# %% [markdown]
# # **Installing dependencies**

# %%
# %pip install langchain_text_splitters
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 165.1 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.4/396.4 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# %pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 40.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# %pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 6.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Working with pdf file**

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('/content/drive/MyDrive/Resume.pdf')
pdf=loader.load()
pdf
# Out:
# [Document(metadata={'source': '/content/drive/MyDrive/Resume.pdf', 'page': 0}, page_content='ABHISHEK PAL  Address:  H No:48, Mawai  Sector -\n9 New Vijay Nagar, \nGhaziabad,  Uttar  Pradesh \nIndia.  \nMobile:  +91-9990050428  \nE-Mail:  Abhishekpal189@gmail.com  \nCareer  Objective  \n \nSeeking  a challenging  work  opportunity  & eager  to become  a part of a well-known  team  who will use my 08 \nyears of experience to create an innovative & cost-effective  system of  Project Management,  Process \nEngineering, New Product Development and Quality Assurance.  \nEmployment  Details  \n \nFoxconn Hon Hai Technology , iPhone  Projects  (Apple Inc).  \n \nGrowth  Path:  December 2023  to Present  \nDesignation:  Sr. Project Management Engineer . \nKey Deliverables:  \n□ Develop project plans from development  to launch  as per t he stake  holder requirements.  \n□ Defining, monitoring  & controlling timelines  & avoid delays.  \n□ New product development ( OEM) and EPM working model 
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=50,chunk_overlap=50)
final=text_splitter.split_documents(pdf)

# %%
print(final[0])
# Out:
# page_content='ABHISHEK PAL  Address:  H No:48, Mawai  Sector -' metadata={'source': '/content/drive/MyDrive/Resume.pdf', 'page': 0}

# %%
print(final[1])
# Out:
# page_content='9 New Vijay Nagar,
# Ghaziabad,  Uttar  Pradesh' metadata={'source': '/content/drive/MyDrive/Resume.pdf', 'page': 0}

# %% [markdown]
# # **Working with text file**

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader('/content/drive/MyDrive/hamlet.txt')
new=loader.load()
new
# Out:
# [Document(metadata={'source': '/content/drive/MyDrive/hamlet.txt'}, page_content="[The Tragedie of Hamlet by William Shakespeare 1599]\n\n\nActus Primus. Scoena Prima.\n\nEnter Barnardo and Francisco two Centinels.\n\n  Barnardo. Who's there?\n  Fran. Nay answer me: Stand & vnfold\nyour selfe\n\n   Bar. Long liue the King\n\n   Fran. Barnardo?\n  Bar. He\n\n   Fran. You come most carefully vpon your houre\n\n   Bar. 'Tis now strook twelue, get thee to bed Francisco\n\n   Fran. For this releefe much thankes: 'Tis bitter cold,\nAnd I am sicke at heart\n\n   Barn. Haue you had quiet Guard?\n  Fran. Not a Mouse stirring\n\n   Barn. Well, goodnight. If you do meet Horatio and\nMarcellus, the Riuals of my Watch, bid them make hast.\nEnter Horatio and Marcellus.\n\n  Fran. I thinke I heare them. Stand: who's there?\n  Hor. Friends to this ground\n\n   Mar. And Leige-men to the Dane\n\n   Fran. Giue you good night\n\n   Mar. O farwel honest Soldier, who hath relieu'd you?\n  Fra. Barnardo ha
# ...

# %%
with open('/content/drive/MyDrive/hamlet.txt') as f:
  speech=f.read()
speech
# Out:
# "[The Tragedie of Hamlet by William Shakespeare 1599]\n\n\nActus Primus. Scoena Prima.\n\nEnter Barnardo and Francisco two Centinels.\n\n  Barnardo. Who's there?\n  Fran. Nay answer me: Stand & vnfold\nyour selfe\n\n   Bar. Long liue the King\n\n   Fran. Barnardo?\n  Bar. He\n\n   Fran. You come most carefully vpon your houre\n\n   Bar. 'Tis now strook twelue, get thee to bed Francisco\n\n   Fran. For this releefe much thankes: 'Tis bitter cold,\nAnd I am sicke at heart\n\n   Barn. Haue you had quiet Guard?\n  Fran. Not a Mouse stirring\n\n   Barn. Well, goodnight. If you do meet Horatio and\nMarcellus, the Riuals of my Watch, bid them make hast.\nEnter Horatio and Marcellus.\n\n  Fran. I thinke I heare them. Stand: who's there?\n  Hor. Friends to this ground\n\n   Mar. And Leige-men to the Dane\n\n   Fran. Giue you good night\n\n   Mar. O farwel honest Soldier, who hath relieu'd you?\n  Fra. Barnardo ha's my place: giue you goodnight.\n\nExit Fran.\n\n  Mar. Holla Barnardo\n\n   Bar
# ...

# %%
text=RecursiveCharacterTextSplitter(chunk_size=50,chunk_overlap=10)
final=text.create_documents([speech])
final
print(final[0])
print(final[1])
# Out:
# page_content='[The Tragedie of Hamlet by William Shakespeare'
# page_content='1599]'

# %%
from langchain_text_splitters import CharacterTextSplitter
text=CharacterTextSplitter(separator="\n\n",chunk_size=100,chunk_overlap=20)
text.split_documents(new)
# print(docs)
# print(text[0])
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 136, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 106, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 296, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 140, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 200, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 190, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 216, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 233, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 103, which is longer than the specified 100
# ...

# %%
with open('/content/drive/MyDrive/hamlet.txt') as f:
  speech=f.read()
speech
text_splitter=CharacterTextSplitter(chunk_size=100,chunk_overlap=20)
text=text_splitter.create_documents([speech])
print(text[0])
print(text[1])
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 136, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 106, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 296, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 140, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 200, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 190, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 216, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 233, which is longer than the specified 100
# WARNING:langchain_text_splitters.base:Created a chunk of size 103, which is longer than the specified 100
# ...

# %% [markdown]
# # **HTML Text Splitters**

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
html_string="""
<!DOCTYPE html>
<html>
<body>
    <div>
        <h1>Foo</h1>
        <p>Some intro text about Foo.</p>
        <div>
            <h2>Bar main section</h2>
            <p>Some intro text about Bar.</p>
            <h3>Bar subsection 1</h3>
            <p>Some text about the first subtopic of Bar.</p>
            <h3>Bar subsection 2</h3>
            <p>Some text about the second subtopic of Bar.</p>
        </div>
        <div>
            <h2>Baz</h2>
            <p>Some text about Baz</p>
        </div>
        <br>
        <p>Some concluding text about Foo</p>
    </div>
</body>
</html>

"""
headers_to_split_on=[("h1","Header 1"),("h2","Header 2"),("h3","Header3")]
text_splitter=HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splits=text_splitter.split_text(html_string)
html_header_splits
# Out:
# [Document(page_content='Foo'),
#  Document(metadata={'Header 1': 'Foo'}, page_content='Some intro text about Foo.  \nBar main section Bar subsection 1 Bar subsection 2'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Bar main section'}, page_content='Some intro text about Bar.'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Bar main section', 'Header3': 'Bar subsection 1'}, page_content='Some text about the first subtopic of Bar.'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Bar main section', 'Header3': 'Bar subsection 2'}, page_content='Some text about the second subtopic of Bar.'),
#  Document(metadata={'Header 1': 'Foo'}, page_content='Baz'),
#  Document(metadata={'Header 1': 'Foo', 'Header 2': 'Baz'}, page_content='Some text about Baz'),
#  Document(metadata={'Header 1': 'Foo'}, page_content='Some concluding text about Foo')]

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
url="https://towardsdatascience.com/recurrent-neural-networks-rnns-3f06d7653a85"
headers_to_split_on=[("h1","Header 1"),("h2","Header 2"),("h3","Header3")]
text_splitter=HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splits=text_splitter.split_text_from_url(url)
html_header_splits
# Out:
# [Document(page_content='Open in app  \nSign up  \nSign in  \nWrite  \nSign up  \nSign in  \nSourceWhat is an RNN?ReferenceForward PassBackward PassComputing GradientsRed arrow shows gradient flowImplementationStep 1: InitializeStep 2: Forward passComputing softmax and numerical stability:Step 3: Compute LossStep 4: Backward passIssuesStep 5: Update weightsStep 6: Repeat steps 2–5Generate TextReferences:  \nRecurrent Neural Networks (RNNs)  \nImplementing an RNN from scratch in Python.'),
#  Document(metadata={'Header 2': 'Implementing an RNN from scratch in Python.'}, page_content='·  \nJavaid Nabi  \nFollow  \nPublished in  \nTowards Data Science  \n·  \n11 min readJul 11, 2019  \n·  \n--  \n10  \nListen  \nShare'),
# ...
